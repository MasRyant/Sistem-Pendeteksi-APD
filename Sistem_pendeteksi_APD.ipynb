# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/PROGRAMS/archive (1).zip"
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
#   inflating: css-data/train/images/IMG_3100_mp4-25_jpg.rf.0a21e9e91348b61c6c1483d6884d2135.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-25_jpg.rf.3313bb2b19a7aa3a0af745abe858ec8e.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-25_jpg.rf.3bbcfef23f20b2cf747256793dcfc615.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-25_jpg.rf.6cee1b67a21808fad2318593379f9986.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-25_jpg.rf.ddd7840e3d846cddfcc13d99f4a6999b.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-2_jpg.rf.4d46f38425296af74814d1f0506575b4.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-2_jpg.rf.58de1db8826e4221df63fd980b823844.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-2_jpg.rf.87e69eb0f5f24cbadcca3fbfe8ca029c.jpg
#   inflating: css-data/train/images/IMG_3100_mp4-2_jpg.rf.bde377ae23066dfe925f09789c2bbdef.jpg
# ...

# %% [markdown]
# 1. **Catatan**:
# Ubah jalur folder untuk data test, train, dan valid pada file ppe_data.yaml yang berada di folder css-data

# %%
# %cd /content/results_yolov8n_100e/kaggle/working

# !yolo task=detect mode=train model=yolov8s.pt data= ppe_data.yaml epochs=3 imgsz=224 plots=True
# Out:
# /content/results_yolov8n_100e/kaggle/working
# ...
# 100% 21.5M/21.5M [00:00<00:00, 118MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU
# ...

# %%
# !yolo task=detect mode=val model=/content/results_yolov8n_100e/kaggle/working/runs/detect/train2/weights/best.pt data= ppe_data.yaml
# Out:
# 2024-07-09 08:39:17.205181: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 08:39:17.205264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 08:39:17.208868: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-09 08:39:17.230601: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !yolo task=detect mode=predict model=/content/results_yolov8n_100e/kaggle/working/runs/detect/train2/weights/best.pt conf=0.25 source=/content/css-data/test/images save=True
# Out:
# 2024-07-09 08:40:08.645170: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 08:40:08.645236: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 08:40:08.646757: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-09 08:40:08.655207: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
Image(filename='/content/results_yolov8n_100e/kaggle/working/runs/detect/train2/val_batch0_pred.jpg', width=1200)
